# %%
import pandas as pd
import os

# %%
# Get a list of all csv files
directory = "electricity"
csv_files = [directory + "/" + file for file in os.listdir(directory) if file.endswith(".csv")]

# Create dataframe of data
results = pd.concat(map(pd.read_csv, csv_files))

# Get a set of all unique configurations
configurations = list(set(tuple(list(i[1].values)) for i in results.iloc[:,3:13].iterrows()))

# Store aggregated results in new dataframe
columns = list(results.columns[3:13])
for col in results.columns[13:]:
    columns.append(col)
    columns.append(col + "_std")
aggregated_results = pd.DataFrame(columns=columns)

# Iterate over all configurations
for config in configurations:
    aggregated_results.loc[len(aggregated_results)] = {
        **dict(zip(results.columns[3:13], config)),
        **dict(zip(results.columns[13:], results[(results.iloc[:,3:13] == config).all(1)].iloc[:,13:].mean())),
        **dict(zip([i + "_std" for i in results.columns[13:]], results[(results.iloc[:,3:13] == config).all(1)].iloc[:,13:].std())),
    }

# Sort data based on validation variogram score
aggregated_results = aggregated_results.sort_values("validation_variogram")

# %%
aggregated_results
# Out:
#      context_length  rnn_layers  rnn_hidden  residual_layers  residual_hidden  \
# 314               2           3       0.500                4              2.0
# 395               2           3       0.500                4              2.0
# 209               2           3       0.500                4              2.0
# 298               1           2       0.333                4              1.0
# 219               4           2       2.000                1              2.0
# ..              ...         ...         ...              ...              ...
# 349               1           2       0.333                1              0.5
# 388               1           4       2.000                2              2.0
# 90                1           3       2.000                2              2.0
# 240               1           4       0.333                4              2.0
# 150               1           4       2.000                1              1.0
#
#      weight_decay  dropout  learning_rate  residual_scaler  anchor_strength  \
# 314       0.00001     0.10         0.0005            False            0.030
# 395       0.00001     0.10         0.0005            False            0.010
# 209       0.00001     0.10         0.0005            False            0.003
# 298       0.00000     0.01         0.0010            False            0.010
# 219       0.00000     0.10         0.0010            False            0.030
# ..            ...      ...            ...              ...              ...
# 349       0.00000     0.10         0.0001             True            0.000
# 388       0.00010     0.10         0.0005             True            0.000
# 90        0.00001     0.00         0.0010             True            0.000
# 240       0.00010     0.10         0.0001             True            0.000
# 150       0.00000     0.10         0.0010             True            0.000
#
#      ...      test_mse  test_mse_std      test_mae  test_mae_std  test_mdae  \
# 314  ...  1.457575e-01  3.923295e-03      0.264462      0.004392   0.188582
# 395  ...  1.468209e-01  3.525180e-03      0.264726      0.004102   0.188799
# 209  ...  1.487882e-01  3.756765e-03      0.265457      0.004399   0.188850
# 298  ...  1.514846e-01  2.165041e-03      0.268588      0.001499   0.191461
# 219  ...  1.523010e-01  1.593848e-03      0.270054      0.002239   0.192113
# ..   ...           ...           ...           ...           ...        ...
# 349  ...  1.328875e+08  2.802024e+08    635.072295   1290.100780  14.134875
# 388  ...  5.393906e+08  8.296056e+08    844.795730   1333.087638   1.273521
# 90   ...  7.732493e+08  1.723289e+09   1092.380632   2397.643355   0.380357
# 240  ...  3.897252e+08  3.131976e+08   1014.907976    621.260231   4.856605
# 150  ...  5.227085e+12  1.168448e+13  34451.594712  75198.149637  24.331878
#
#      test_mdae_std  test_crps_sum  test_crps_sum_std  test_variogram  \
# 314       0.004404   1.102481e+01       4.776403e-01        0.056832
# 395       0.004146   1.115644e+01       3.916856e-01        0.057007
# 209       0.004370   1.118544e+01       2.741015e-01        0.057311
# 298       0.001470   1.099457e+01       6.512152e-01        0.057904
# 219       0.002683   1.270672e+01       6.791502e-01        0.058109
# ..             ...            ...                ...             ...
# 349      26.640467   7.991392e+04       1.464267e+05     3632.757551
# 388       0.332823   1.563404e+05       2.405927e+05     4398.792214
# 90        0.260290   1.610171e+05       3.471060e+05     5713.817196
# 240       1.864570   1.940476e+05       1.106729e+05     5982.754190
# 150      36.884442   2.087900e+06       4.553967e+06    30198.173188
#
#      test_variogram_std
# 314            0.001122
# 395            0.001059
# 209            0.001099
# 298            0.000249
# 219            0.000514
# ..                  ...
# 349         7392.776331
# 388         7119.983092
# 90         12497.892546
# 240         3589.408138
# 150        64201.695655
#
# [400 rows x 30 columns]
