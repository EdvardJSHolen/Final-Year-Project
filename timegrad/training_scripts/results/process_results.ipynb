# %%
import pandas as pd
import os

# %%
# Get a list of all csv files
directory = "solar"
csv_files = [directory + "/" + file for file in os.listdir(directory) if file.endswith(".csv")]

# Create dataframe of data
results = pd.concat(map(pd.read_csv, csv_files))

# Get a set of all unique configurations
configurations = list(set(tuple(list(i[1].values)) for i in results.iloc[:,3:13].iterrows()))

# Store aggregated results in new dataframe
columns = list(results.columns[3:13])
for col in results.columns[13:]:
    columns.append(col)
    columns.append(col + "_std")
aggregated_results = pd.DataFrame(columns=columns)

# Iterate over all configurations
for config in configurations:
    aggregated_results.loc[len(aggregated_results)] = {
        **dict(zip(results.columns[3:13], config)),
        **dict(zip(results.columns[13:], results[(results.iloc[:,3:13] == config).all(1)].iloc[:,13:].mean())),
        **dict(zip([i + "_std" for i in results.columns[13:]], results[(results.iloc[:,3:13] == config).all(1)].iloc[:,13:].std())),
    }

# Sort data based on validation variogram score
aggregated_results = aggregated_results.sort_values("validation_variogram")

# %%
aggregated_results
# Out:
#     num_layers  num_cells  dropout  diff_steps beta_schedule  residual_layers  \
# 28           3         20     0.10         100        linear                4
# 31           2         20     0.00         100          quad               16
# 34           1         60     0.01         100          quad               16
# 1            1         40     0.00          50        linear               16
# 18           3         40     0.00         100        linear               16
# 39           3         40     0.01         100          quad                8
# 40           3         20     0.00          50        linear                8
# 38           1         60     0.01         100        linear                4
# 9            2         40     0.10         100        linear                8
# 30           3         20     0.00         100        linear                8
# 32           2         60     0.00         100          quad               16
# 0            2         20     0.01          50          quad                4
# 15           3         20     0.00         100        linear                4
# 2            3         40     0.10         100        linear                4
# 44           2         40     0.10         100          quad               16
# 29           2         20     0.01          50        linear               16
# 3            1         60     0.00         100        linear                8
# 45           3         20     0.00          50        linear               16
# 12           2         40     0.10          25        linear                4
# 36           2         40     0.10          50          quad                8
# 23           1         20     0.00          50        linear                8
# 16           2         20     0.01         100        linear                4
# 13           2         60     0.10          50        linear                8
# 25           3         40     0.01          50        linear                4
# 19           3         20     0.01         100          quad                4
# 14           3         20     0.10         100          quad                4
# 43           1         60     0.01          50          quad                4
# 24           1         60     0.10          25          quad                4
# 7            1         60     0.10          50          quad                4
# 20           3         20     0.10          25        linear                8
# 42           2         20     0.10          50          quad               16
# 11           2         20     0.10          50        linear               16
# 46           3         40     0.10         100          quad               16
# 21           2         40     0.00          50          quad               16
# 8            2         40     0.00         100        linear               16
# 4            1         60     0.00          25          quad               16
# 10           1         40     0.00          50          quad                8
# 26           2         20     0.00          25        linear                4
# 22           1         20     0.10          50          quad               16
# 5            2         20     0.10          25          quad                4
# 37           1         20     0.00          25        linear                8
# 33           3         20     0.01          25          quad                4
# 27           1         60     0.00          25          quad                4
# 6            1         40     0.10          25        linear               16
# 41           2         60     0.00          25          quad               16
# 35           2         20     0.10          25          quad               16
# 17           1         20     0.00          25          quad               16
#
#     scaling  context_length  learning_rate  gradient_clipping  validation_mse  \
# 28    False               2         0.0100              100.0        0.135258
# 31    False               1         0.0001               10.0        0.136014
# 34    False               1         0.0001            10000.0        0.128025
# 1     False               2         0.0001               10.0        0.135817
# 18    False               1         0.0010               10.0        0.128655
# 39    False               1         0.0010               10.0        0.141470
# 40    False               1         0.0010               10.0        0.133695
# 38    False               2         0.0100              100.0        0.123752
# 9     False               3         0.0100              100.0        0.144040
# 30    False               2         0.0001              100.0        0.133358
# 32    False               2         0.0100            10000.0        0.130163
# 0     False               3         0.0001              100.0        0.124967
# 15    False               3         0.0010            10000.0        0.121878
# 2     False               1         0.0010              100.0        0.168785
# 44    False               3         0.0001               10.0        0.141654
# 29    False               2         0.0100              100.0        0.139960
# 3      True               3         0.0100               10.0        0.142272
# 45    False               2         0.0100               10.0        0.137399
# 12    False               3         0.0100              100.0        0.135615
# 36    False               3         0.0001            10000.0        0.143743
# 23     True               2         0.0010               10.0        0.241725
# 16     True               3         0.0100              100.0        0.167484
# 13     True               2         0.0010               10.0        0.224661
# 25     True               2         0.0100            10000.0        0.171551
# 19     True               2         0.0001              100.0        0.168156
# 14     True               2         0.0010              100.0        0.177212
# 43     True               3         0.0010              100.0        0.312457
# 24    False               3         0.0001               10.0        0.245162
# 7      True               1         0.0001            10000.0        0.336442
# 20    False               3         0.0010              100.0        0.267837
# 42    False               2         0.0001              100.0        0.440511
# 11     True               1         0.0001            10000.0        0.599759
# 46     True               1         0.0010              100.0        0.380369
# 21     True               3         0.0100            10000.0        0.459813
# 8      True               1         0.0100               10.0        0.156931
# 4     False               3         0.0100            10000.0        0.513742
# 10     True               3         0.0100               10.0        0.539819
# 26     True               1         0.0001              100.0        0.543464
# 22     True               2         0.0010               10.0        0.798499
# 5      True               3         0.0001            10000.0        0.821952
# 37     True               2         0.0001            10000.0        0.748109
# 33     True               1         0.0100            10000.0        0.888141
# 27     True               1         0.0010            10000.0        0.799169
# 6      True               3         0.0001            10000.0        0.835175
# 41     True               3         0.0010              100.0        0.911721
# 35     True               3         0.0001              100.0        0.933231
# 17     True               1         0.0100              100.0        0.941590
#
#     validation_mse_std  validation_mae  validation_mae_std  validation_mdae  \
# 28            0.019057        0.151044            0.008016         0.000258
# 31            0.003112        0.146942            0.020361         0.000280
# 34            0.007924        0.146772            0.008223         0.000218
# 1             0.015449        0.159038            0.009811         0.000206
# 18            0.017795        0.135800            0.009574         0.000262
# 39            0.012875        0.147516            0.016154         0.000180
# 40            0.025806        0.157168            0.020933         0.000237
# 38            0.008621        0.144505            0.008845         0.000356
# 9             0.008795        0.157865            0.011509         0.000229
# 30            0.013593        0.153964            0.011219         0.000323
# 32            0.009860        0.137562            0.007852         0.000206
# 0             0.008513        0.149417            0.005688         0.000238
# 15            0.006562        0.143180            0.007913         0.000642
# 2             0.030818        0.170188            0.025164         0.000279
# 44            0.017871        0.151945            0.014442         0.000164
# 29            0.023685        0.162657            0.018914         0.000214
# 3             0.018492        0.171910            0.012359         0.000161
# 45            0.019319        0.156161            0.011686         0.000225
# 12            0.014912        0.162465            0.010950         0.000183
# 36            0.015561        0.176766            0.015321         0.000172
# 23            0.026482        0.240037            0.014922         0.000132
# 16            0.013544        0.191494            0.008413         0.000248
# 13            0.020644        0.224420            0.012671         0.000110
# 25            0.013532        0.189068            0.011248         0.000141
# 19            0.015434        0.186651            0.010176         0.000140
# 14            0.005075        0.195660            0.004244         0.000133
# 43            0.055215        0.284141            0.026272         0.000131
# 24            0.051124        0.253412            0.027656         0.000230
# 7             0.083593        0.284857            0.042992         0.000128
# 20            0.073081        0.265477            0.039710         0.000148
# 42            0.062853        0.346223            0.023580         0.000176
# 11            0.046549        0.390187            0.014462         0.000118
# 46            0.048448        0.299373            0.022930         0.000090
# 21                 NaN        0.348247                 NaN         0.000128
# 8             0.008575        0.173274            0.003360         0.000167
# 4             0.045010        0.366269            0.017243         0.000146
# 10            0.051495        0.376791            0.016783         0.000110
# 26            0.135516        0.368400            0.052357         0.000927
# 22            0.045715        0.457961            0.013961         0.000105
# 5             0.023501        0.466145            0.006902         0.000109
# 37            0.063554        0.443085            0.019213         0.000130
# 33            0.017205        0.484251            0.005165         0.000102
# 27            0.018054        0.458902            0.005657         0.000125
# 6             0.031652        0.470283            0.009763         0.000110
# 41            0.008694        0.495475            0.002110         0.000082
# 35            0.020129        0.501384            0.005762         0.000072
# 17            0.080319        0.502380            0.023292         0.000090
#
#     validation_mdae_std  validation_crps_sum  validation_crps_sum_std  \
# 28         5.773560e-05            15.789103                 1.350852
# 31         1.427555e-05            13.848347                 2.974849
# 34         4.274732e-05            14.379081                 1.160745
# 1          2.844782e-05            16.189895                 1.557314
# 18         4.416300e-05            13.270956                 1.461076
# 39         3.059991e-05            15.013273                 2.262652
# 40         5.344308e-05            15.822422                 3.291177
# 38         9.878151e-05            14.328740                 1.346637
# 9          4.896413e-05            16.518623                 1.538309
# 30         1.287855e-04            15.597905                 1.707331
# 32         1.912198e-05            13.107230                 1.013226
# 0          4.360173e-05            14.364210                 0.880910
# 15         6.660180e-04            13.569412                 0.923015
# 2          6.162145e-05            18.610943                 3.625168
# 44         2.266345e-05            15.104517                 1.992954
# 29         2.361398e-05            16.215564                 3.098910
# 3          2.609211e-05            18.032685                 1.625562
# 45         4.044378e-05            15.232449                 1.724857
# 12         2.990458e-05            16.515644                 1.719782
# 36         3.752632e-05            18.349412                 2.359484
# 23         1.483605e-05            27.468584                 2.097959
# 16         3.608155e-05            20.806751                 1.285604
# 13         1.683578e-05            25.487813                 1.510819
# 25         2.064345e-05            20.244991                 1.972317
# 19         2.097792e-05            19.505938                 1.836468
# 14         3.189277e-05            21.256748                 0.902371
# 43         2.571697e-05            34.259770                 3.520511
# 24         6.923610e-05            29.593375                 3.966130
# 7          2.307016e-05            34.100233                 6.122039
# 20         2.634366e-05            31.037287                 5.837797
# 42         7.713503e-06            42.068517                 3.206952
# 11         1.480903e-05            48.344775                 2.050308
# 46         6.136313e-06            33.972242                 2.948962
# 21                  NaN            43.481512                      NaN
# 8          2.288689e-05            16.625750                 0.554342
# 4          2.093755e-05            46.157636                 2.411237
# 10         2.739284e-05            47.563774                 2.328887
# 26         1.738015e-03            46.910084                 7.535949
# 22         1.423590e-05            59.257666                 1.965715
# 5          4.486613e-05            61.209675                 1.133531
# 37         2.534181e-05            57.639177                 2.824121
# 33         2.129011e-05            64.103325                 0.790023
# 27         2.620515e-05            60.461236                 0.832724
# 6          1.172182e-05            61.704314                 1.386831
# 41         7.305898e-07            65.771816                 0.268867
# 35         1.500409e-05            66.585293                 0.815769
# 17         1.555651e-05            66.963592                 3.202924
#
#     validation_variogram  validation_variogram_std
# 28              0.026246                  0.000350
# 31              0.026248                  0.000515
# 34              0.026516                  0.001325
# 1               0.026523                  0.001411
# 18              0.026627                  0.001738
# 39              0.027040                  0.001942
# 40              0.027560                  0.001493
# 38              0.027602                  0.001656
# 9               0.027835                  0.002267
# 30              0.027973                  0.001322
# 32              0.028014                  0.001550
# 0               0.028049                  0.000530
# 15              0.028189                  0.002229
# 2               0.028284                  0.002147
# 44              0.028664                  0.001981
# 29              0.028847                  0.002457
# 3               0.029010                  0.001325
# 45              0.029272                  0.002653
# 12              0.029370                  0.001643
# 36              0.031911                  0.001205
# 23              0.032205                  0.001053
# 16              0.032366                  0.001528
# 13              0.032731                  0.000948
# 25              0.032934                  0.002520
# 19              0.034902                  0.002206
# 14              0.035143                  0.001283
# 43              0.035150                  0.002341
# 24              0.035503                  0.002263
# 7               0.035763                  0.002505
# 20              0.036067                  0.001279
# 42              0.036210                  0.000808
# 11              0.037289                  0.000576
# 46              0.037558                  0.000771
# 21              0.037687                       NaN
# 8               0.037714                  0.001739
# 4               0.038341                  0.000421
# 10              0.038397                  0.000662
# 26              0.039808                  0.003046
# 22              0.043896                  0.001677
# 5               0.043967                  0.001111
# 37              0.044484                  0.001526
# 33              0.046024                  0.001305
# 27              0.046102                  0.001304
# 6               0.047711                  0.001266
# 41              0.052745                  0.001839
# 35              0.054240                  0.001434
# 17              0.057459                  0.001857
