# %%
import pandas as pd
import os

# %%
# Get a list of all csv files
directory = "solar"
csv_files = [directory + "/" + file for file in os.listdir(directory) if file.endswith(".csv")]

# Create dataframe of data
results = pd.concat(map(pd.read_csv, csv_files))

# Get a set of all unique configurations
configurations = list(set(tuple(list(i[1].values)) for i in results.iloc[:,3:14].iterrows()))

# Store aggregated results in new dataframe
columns = list(results.columns[3:14])
for col in results.columns[14:]:
    columns.append(col)
    columns.append(col + "_std")
aggregated_results = pd.DataFrame(columns=columns)

# Iterate over all configurations
for config in configurations:
    aggregated_results.loc[len(aggregated_results)] = {
        **dict(zip(results.columns[3:14], config)),
        **dict(zip(results.columns[14:], results[(results.iloc[:,3:14] == config).all(1)].iloc[:,14:].mean())),
        **dict(zip([i + "_std" for i in results.columns[14:]], results[(results.iloc[:,3:14] == config).all(1)].iloc[:,14:].std())),
    }

# Sort data based on validation variogram score
aggregated_results = aggregated_results.sort_values("validation_variogram")

# %%
aggregated_results
# Out:
#      context_length  rnn_layers  rnn_hidden  residual_layers  residual_hidden  \
# 21                4           3       0.500                4            2.000
# 33                4           3       0.500                4            2.000
# 35                4           3       0.500                4            2.000
# 108               4           3       0.500                4            2.000
# 29                2           2       1.000                2            2.000
# ..              ...         ...         ...              ...              ...
# 55                1           3       0.500                8            0.500
# 109               4           2       2.000                8            0.333
# 66                2           3       1.000                1            0.333
# 72                4           2       0.333                2            0.333
# 73                1           3       0.500                8            0.500
#
#      weight_decay  dropout  learning_rate  residual_scaler  mean_scaler  ...  \
# 21         0.0000     0.01         0.0010            False        False  ...
# 33         0.0000     0.01         0.0010            False        False  ...
# 35         0.0000     0.01         0.0010            False        False  ...
# 108        0.0000     0.01         0.0010            False        False  ...
# 29         0.0000     0.01         0.0010            False        False  ...
# ..            ...      ...            ...              ...          ...  ...
# 55         0.0001     0.00         0.0001             True        False  ...
# 109        0.0001     0.10         0.0001             True         True  ...
# 66         0.0001     0.00         0.0001             True         True  ...
# 72         0.0001     0.10         0.0001             True        False  ...
# 73         0.0001     0.00         0.0001             True        False  ...
#
#      validation_mse  validation_mse_std  validation_mae  validation_mae_std  \
# 21         0.163216            0.020158        0.201535            0.010257
# 33         0.168076            0.021614        0.203943            0.010334
# 35         0.158844            0.016481        0.199486            0.008806
# 108        0.171647            0.022913        0.205938            0.011790
# 29         0.143176            0.023128        0.187242            0.015128
# ..              ...                 ...             ...                 ...
# 55         1.061193            0.026346        0.911838            0.003757
# 109        3.226295            3.884413        0.768949            0.253927
# 66         2.467939            2.141332        0.780823            0.106809
# 72         1.648425            0.032222        0.931063            0.011908
# 73         1.658048            0.101194        0.922310            0.019595
#
#      validation_mdae  validation_mdae_std  validation_crps_sum  \
# 21          0.006552             0.001091            17.798117
# 33          0.006489             0.001092            18.117884
# 35          0.006735             0.001134            17.567790
# 108         0.006498             0.001133            18.423840
# 29          0.008841             0.001248            15.483592
# ..               ...                  ...                  ...
# 55          0.860044             0.022189            75.595119
# 109         0.223287             0.104264            77.824389
# 66          0.304254             0.045488            82.645921
# 72          0.615460             0.013443            87.819419
# 73          0.586563             0.011360            83.633699
#
#      validation_crps_sum_std  validation_variogram  validation_variogram_std
# 21                  1.652545              0.044734                  0.000659
# 33                  1.635766              0.044850                  0.000664
# 35                  1.352190              0.044901                  0.000665
# 108                 1.753083              0.044962                  0.000722
# 29                  1.774338              0.046231                  0.001621
# ..                       ...                   ...                       ...
# 55                  0.877491              2.550810                  0.359012
# 109                 9.267010              2.675634                  4.173874
# 66                  8.130733              2.705491                  2.027958
# 72                  0.885040              4.215099                  0.070923
# 73                  1.628289              4.732017                  0.889859
#
# [200 rows x 21 columns]
