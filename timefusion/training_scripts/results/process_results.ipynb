# %%
import pandas as pd
import os

# %%
# Get a list of all csv files
directory = "electricity"
csv_files = [directory + "/" + file for file in os.listdir(directory) if file.endswith(".csv")]

# Create dataframe of data
results = pd.concat(map(pd.read_csv, csv_files))

# Get a set of all unique configurations
configurations = list(set(tuple(list(i[1].values)) for i in results.iloc[:,3:13].iterrows()))

# Store aggregated results in new dataframe
columns = list(results.columns[3:13])
for col in results.columns[13:]:
    columns.append(col)
    columns.append(col + "_std")
aggregated_results = pd.DataFrame(columns=columns)

# Iterate over all configurations
for config in configurations:
    aggregated_results.loc[len(aggregated_results)] = {
        **dict(zip(results.columns[3:13], config)),
        **dict(zip(results.columns[13:], results[(results.iloc[:,3:13] == config).all(1)].iloc[:,13:].mean())),
        **dict(zip([i + "_std" for i in results.columns[13:]], results[(results.iloc[:,3:13] == config).all(1)].iloc[:,13:].std())),
    }

# Sort data based on validation variogram score
aggregated_results = aggregated_results.sort_values("validation_variogram")

# %%
aggregated_results
# Out:
#      context_length  rnn_layers  rnn_hidden  residual_layers  residual_hidden
# 169               1           3       0.500                4            2.000  \
# 162               1           3       0.500                4            2.000
# 33                1           3       0.500                4            2.000
# 47                1           3       0.500                4            2.000
# 70                1           4       0.333                4            0.333
# ..              ...         ...         ...              ...              ...
# 122               1           2       1.000                1            1.000
# 101               2           3       0.333                4            0.333
# 55                1           3       0.500                1            2.000
# 75                1           4       0.333                4            1.000
# 34                1           4       0.333                2            2.000
#
#      weight_decay  dropout  learning_rate  residual_scaler  anchor_strength
# 169       0.00001     0.01         0.0005            False            0.030  \
# 162       0.00001     0.01         0.0005            False            0.010
# 33        0.00001     0.01         0.0005            False            0.003
# 47        0.00001     0.01         0.0005            False            0.000
# 70        0.00000     0.00         0.0010            False            0.030
# ..            ...      ...            ...              ...              ...
# 122       0.00000     0.10         0.0005             True            0.000
# 101       0.00001     0.01         0.0001             True            0.000
# 55        0.00001     0.01         0.0005             True            0.000
# 75        0.00000     0.01         0.0010             True            0.000
# 34        0.00001     0.10         0.0001             True            0.000
#
#      validation_mse  validation_mse_std  validation_mae  validation_mae_std
# 169    1.810996e-01        5.317065e-03        0.290131            0.005773  \
# 162    1.833533e-01        5.973836e-03        0.291092            0.005953
# 33     1.867227e-01        6.180289e-03        0.292186            0.005922
# 47     1.940261e-01        6.780570e-03        0.293476            0.005804
# 70     1.856923e-01        1.003493e-02        0.294593            0.009746
# ..              ...                 ...             ...                 ...
# 122    6.839255e+06        1.529304e+07       35.082735           77.224434
# 101    3.773545e+04        2.261366e+04       28.291135           13.454281
# 55     1.659008e+07        2.226804e+07       64.365393           50.214384
# 75     2.271224e+07        1.996994e+07       79.624781           49.134604
# 34     2.439677e+07        2.626290e+07       95.815502           93.430537
#
#      validation_mdae  validation_mdae_std  validation_crps_sum
# 169         0.204124             0.005249            12.297340  \
# 162         0.205055             0.005484            12.443557
# 33          0.205253             0.005694            12.620427
# 47          0.205511             0.005229            12.618226
# 70          0.208445             0.008856            11.579243
# ..               ...                  ...                  ...
# 122         0.673180             0.574053          7970.691056
# 101         4.613595             0.972657          4438.286819
# 55          0.349379             0.214051         17476.133832
# 75          0.264511             0.082724         19718.969740
# 34          2.839991             1.731490         20714.728137
#
#      validation_crps_sum_std  validation_variogram  validation_variogram_std
# 169                 0.779828              0.063626                  0.001224
# 162                 0.912154              0.063899                  0.001230
# 33                  0.876187              0.064186                  0.001230
# 47                  0.970657              0.064624                  0.001234
# 70                  0.406382              0.065082                  0.002230
# ..                       ...                   ...                       ...
# 122             17674.489965            180.636348                403.598543
# 101              1953.241309            264.458156                138.942387
# 55              14644.208312            377.144233                311.033773
# 75              11631.014851            429.332704                254.646157
# 34              20180.663342            500.019477                521.463184
#
# [196 rows x 20 columns]
